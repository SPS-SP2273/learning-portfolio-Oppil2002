# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 Important concepts

# %% [markdown]
# ## 1.1 Path

# %% [markdown]
# ## 1.2 More about relative paths

# %% [markdown]
# ### macOS or Linux

# %%
~\Desktop
# Out:
#   Cell In[1], line 1
#     ~\Desktop
#       ^
# SyntaxError: unexpected character after line continuation character

# %%
# I don't understand what I'm doing here

# %% [markdown]
# ## 1.3 Path separator

# %% [markdown]
# ## 1.4 Text files vs. Binary files

# %% [markdown]
# ## 1.5 Extensions

# %% [markdown]
# # 2 Opening and closing files

# %% [markdown]
# ## 2.1 Reading data

# %%
with open('spectrum-01.txt', 'r') as f:
    contents = f.read()

print(contents)
# Out:
# Light Intensity, Ch A vs Actual Angular Position, Run #4
# Actual Angular Position (  )	Light Intensity, Ch A ( % max )
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.3
# 0.000	-0.2
# 0.000	-0.2
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.004	-0.1
# 0.010	-0.2
# 0.018	-0.2
# 0.024	-0.3
# 0.029	-0.3
# 0.033	-0.3
# 0.036	-0.2
# 0.039	-0.1
# 0.043	-0.1
# 0.047	-0.1
# 0.053	-0.1
# 0.060	-0.1
# 0.066	-0.1
# 0.069	-0.1
# 0.073	-0.1
# 0.076	-0.1
# 0.079	-0.1
# 0.081	-0.1
# 0.082	-0.1
# 0.083	-0.2
# 0.083	-0.2
# 0.086	-0.2
# 0.090	-0.2
# 0.095	-0.2
# 0.100	-0.3
# 0.103	-0.3
# 0.104	-0.2
# 0.105	-0.3
# 0.107	-0.2
# 0.110	-0.2
# 0.115	-0.1
# 0.122	-0.2
# 0.128	-0.1
# 0.134	-0.2
# 0.139	-0.1
# 0.144	-0.2
# 0.150	-0.2
# 0.157	-0.2
# 0.164	-0.2
# 0.170	-0.3
# 0.175	-0.3
# 0.180	-0.2
# 0.185	-0.2
# 0.191	-0.1
# 0.195	-0.1
# ...

# %%
# Does it work if I just print directly?

with open('spectrum-01.txt', 'r') as f:
    print(f.read())
# Out:
# Light Intensity, Ch A vs Actual Angular Position, Run #4
# Actual Angular Position (  )	Light Intensity, Ch A ( % max )
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.1
# 0.000	-0.1
# 0.000	-0.2
# 0.000	-0.3
# 0.000	-0.2
# 0.000	-0.2
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.001	-0.1
# 0.004	-0.1
# 0.010	-0.2
# 0.018	-0.2
# 0.024	-0.3
# 0.029	-0.3
# 0.033	-0.3
# 0.036	-0.2
# 0.039	-0.1
# 0.043	-0.1
# 0.047	-0.1
# 0.053	-0.1
# 0.060	-0.1
# 0.066	-0.1
# 0.069	-0.1
# 0.073	-0.1
# 0.076	-0.1
# 0.079	-0.1
# 0.081	-0.1
# 0.082	-0.1
# 0.083	-0.2
# 0.083	-0.2
# 0.086	-0.2
# 0.090	-0.2
# 0.095	-0.2
# 0.100	-0.3
# 0.103	-0.3
# 0.104	-0.2
# 0.105	-0.3
# 0.107	-0.2
# 0.110	-0.2
# 0.115	-0.1
# 0.122	-0.2
# 0.128	-0.1
# 0.134	-0.2
# 0.139	-0.1
# 0.144	-0.2
# 0.150	-0.2
# 0.157	-0.2
# 0.164	-0.2
# 0.170	-0.3
# 0.175	-0.3
# 0.180	-0.2
# 0.185	-0.2
# 0.191	-0.1
# 0.195	-0.1
# ...

# %%
# It does!

# %% [markdown]
# ## 2.2 Writing data

# %%
text = "According to all known laws of aviation, there is no way a bee should be able to fly. Its wings are too small to get its fat little body off the ground. The bee, of course, flies anyway because bees don't care what humans think is impossible. Yellow, black. Yellow, black. Yellow, black. Yellow, black. Ooh, black and yellow! Let's shake it up a little. Barry! Breakfast is ready! Ooming! Hang on a second. Hello? - Barry? - Adam? - Oan you believe this is happening? - I can't. I'll pick you up. Looking sharp. Use the stairs. Your father paid good money for those. Sorry. I'm excited. Here's the graduate. We're very proud of you, son. A perfect report card, all B's. Very proud. Ma! I got a thing going here. - You got lint on your fuzz. - Ow! That's me! - Wave to us! We'll be in row 118,000. - Bye! Barry, I told you, stop flying in the house! - Hey, Adam. - Hey, Barry. - Is that fuzz gel? - A little. Special day, graduation. Never thought I'd make it. Three days grade school, three days high school. Those were awkward. Three days college. I'm glad I took a day and hitchhiked around the hive. You did come back different. - Hi, Barry. - Artie, growing a mustache? Looks good. - Hear about Frankie? - Yeah. - You going to the funeral? - No, I'm not going. Everybody knows, sting someone, you die. Don't waste it on a squirrel. Such a hothead. I guess he could have just gotten out of the way. I love this incorporating an amusement park into our day. That's why we don't need vacations. Boy, quite a bit of pomp... under the circumstances. - Well, Adam, today we are men. - We are! - Bee-men. - Amen! Hallelujah! Students, faculty, distinguished bees, please welcome Dean Buzzwell. Welcome, New Hive Oity graduating class of... ...9:15. That concludes our ceremonies. And begins your career at Honex Industries! Will we pick ourjob today? I heard it's just orientation. Heads up! Here we go."

# %% [markdown]
# ### Writing to a file in one go

# %%
with open('my-text-once.txt', 'w') as file:
    file.write(text)

# %% [markdown]
# ### Writing to a file, line by line

# %%
with open('my-text-lines.txt', 'w') as file:
    for line in text.splitlines():
        file.writelines(line)

# %%
with open('my-text-lines.txt','r') as file:
    content=file.read()

print(content)
# Out:
# According to all known laws of aviation, there is no way a bee should be able to fly. Its wings are too small to get its fat little body off the ground. The bee, of course, flies anyway because bees don't care what humans think is impossible. Yellow, black. Yellow, black. Yellow, black. Yellow, black. Ooh, black and yellow! Let's shake it up a little. Barry! Breakfast is ready! Ooming! Hang on a second. Hello? - Barry? - Adam? - Oan you believe this is happening? - I can't. I'll pick you up. Looking sharp. Use the stairs. Your father paid good money for those. Sorry. I'm excited. Here's the graduate. We're very proud of you, son. A perfect report card, all B's. Very proud. Ma! I got a thing going here. - You got lint on your fuzz. - Ow! That's me! - Wave to us! We'll be in row 118,000. - Bye! Barry, I told you, stop flying in the house! - Hey, Adam. - Hey, Barry. - Is that fuzz gel? - A little. Special day, graduation. Never thought I'd make it. Three days grade school, three days hi
# ...

# %% [markdown]
# # 3 Some useful packages

# %%
import os
import glob
import shutil

# %% [markdown]
# # 4 OS safe paths

# %%
path = os.path.join('.', 'all-data', 'sg-data', 'data-01.txt')
print(path)
# Out:
# ./all-data/sg-data/data-01.txt

# %% [markdown]
# # 5 Folders

# %% [markdown]
# ## 5.1 Creating folders

# %%
os.mkdir('people')

for person in ['John', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    print(f'Creating {path}')
    os.mkdir(path)
# Out:
# Creating people/John
# Creating people/Paul
# Creating people/Ringo

# %%
os.mkdir('Test2')

for folder in ['Folder 1','Folder 2']:
    path = os.path.join('Test', folder)

# %%
print(path)
# Out:
# Test/Folder 2

# %% [markdown]
# ## 5.2 Checking for existence

# %% [markdown]
# ### Using try-except

# %%
for person in ['John', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    try:
        os.mkdir(path)
        print(f'Creating {path}')
    except FileExistsError:
        print(f'{path} already exists; skipping creation.')
# Out:
# people/John already exists; skipping creation.
# people/Paul already exists; skipping creation.
# people/Ringo already exists; skipping creation.

# %%
for folder in ['Folder 1','Folder 2']:
    path = os.path.join('Test', folder)
    try:
        os.mkdir(path)
        print(f'creating {path}')
    except FileExistsError:
        print(f'{path} exists.')
# Out:
# creating Test/Folder 1
# Test/Folder 2 exists.

# %% [markdown]
# ### Using os.path.exists()

# %%
for person in ['John', 'Paul', 'Ringo']:
    path = os.path.join('people', person)
    if os.path.exists(path):
        print(f'{path} already exists; skipping creation.')
    else:
        os.mkdir(path)
        print(f'Creating {path}')
# Out:
# people/John already exists; skipping creation.
# people/Paul already exists; skipping creation.
# people/Ringo already exists; skipping creation.

# %%
for folder in ['Folder 1','Folder 2','Folder 3']:
    path = os.path.join('Test', folder)
    if os.path.exists(path):
        print(f'{path} exists')
    else:
        os.mkdir(path)
        print(f'Creating {path}')
# Out:
# Test/Folder 1 exists
# Test/Folder 2 exists
# Creating Test/Folder 3

# %% [markdown]
# ## 5.3 Copying files

# %%
for person in ['John', 'Paul', 'Ringo']:
    path_to_destination = os.path.join('people', person)
    shutil.copy('random.png', path_to_destination)
    print(f'Copied file to {path_to_destination}')
# Out:
# Copied file to people/John
# Copied file to people/Paul
# Copied file to people/Ringo

# %%
for folder in ['Folder 1','Folder 2','Folder 3']:
    path_to_destination = os.path.join('Test', folder)
    shutil.copy('random.png', path_to_destination)
    print(f'Copied file to {path_to_destination}')
# Out:
# Copied file to Test/Folder 1
# Copied file to Test/Folder 2
# Copied file to Test/Folder 3

# %%
for person in ['John', 'Paul', 'Ringo']:
    # Create folder 'imgs'
    path_to_imgs = os.path.join('people', person, 'imgs')
    if not os.path.exists(path_to_imgs):
        os.mkdir(path_to_imgs)

    # Move logo file
    current_path_of_logo = os.path.join('people', person, 'random.png')
    new_path_of_logo = os.path.join('people', person, 'imgs', 'random.png')

    shutil.move(current_path_of_logo, new_path_of_logo)
    print(f'Moved logo to {new_path_of_logo}')
# Out:
# Moved logo to people/John/imgs/random.png
# Moved logo to people/Paul/imgs/random.png
# Moved logo to people/Ringo/imgs/random.png

# %%
for folder in ['Folder 1','Folder 2','Folder 3']:
    path_to_imgs = os.path.join('Test', folder, 'imgs')
    if not os.path.exists(path_to_imgs):
        os.mkdir(path_to_imgs)
    # Does this 'if not' statement check for the existance of files? Like if it does not exist, it creates? Interesting... no need for else statements

    current_logo = os.path.join('Test',folder,'random.png')
    new_path = os.path.join('Test',folder,'imgs','random.png')
    shutil.move(current_logo, new_path)
    print(f'Moved to {new_path}')
# Out:
# Moved to Test/Folder 1/imgs/random.png
# Moved to Test/Folder 2/imgs/random.png
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniconda3/lib/python3.11/shutil.py:825, in move(src, dst, copy_function)
#     824 try:
# --> 825     os.rename(src, real_dst)
#     826 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Test/Folder 3/random.png' -> 'Test/Folder 3/imgs/random.png'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 9
#       7 current_logo = os.path.join('Test',folder,'random.png')
#       8 new_path = os.path.join('Test',folder,'imgs','random.png')
# ----> 9 shutil.move(current_logo, new_path)
#      10 print(f'Moved to {new_path}')
#
# ...

# %%
# Pls ignore the error. I mistakenly ran the last few lines of moving files outside of the "for" block so it moved Folder 3's img on the first run
# When I fixed it and ran the line again it could not find folder 3's img

# %% [markdown]
# # 6 Listing and looking for files

# %%
glob.glob('*')
# Out:
# ['my-text-once.txt',
#  'Test',
#  'files,_folders_&_os_(need).ipynb',
#  'random.png',
#  'spectrum-01.txt',
#  'people',
#  'my-text-lines.txt',
#  'Test2']

# %%
glob.glob('peo*')
# Out:
# ['people']

# %%
glob.glob('Test*')
# Out:
# ['Test', 'Test2']

# %%
glob.glob('peo*/*')
# Out:
# ['people/Paul', 'people/John']

# %%
glob.glob('Test*/*')
# Out:
# ['Test/Folder 3', 'Test/Folder 2', 'Test/Folder 1']

# %%
glob.glob('people/**', recursive=True)
# Out:
# ['people/',
#  'people/Paul',
#  'people/Paul/imgs',
#  'people/Paul/imgs/random.png',
#  'people/John',
#  'people/John/imgs',
#  'people/John/imgs/random.png']

# %%
glob.glob('people/**/*.png', recursive=True)
# Out:
# ['people/Paul/imgs/random.png', 'people/John/imgs/random.png']

# %% [markdown]
# # 7 Extracting file info

# %%
path = 'people/Ringo/imgs/random.png'
filename = path.split(os.path.sep)[-1]
extension = filename.split('.')[-1]
print(filename, extension)
# Out:
# random.png png

# %% [markdown]
# # 8 Deleting stuff

# %%
os.remove('Test/Folder 1/imgs/random.png')

# %%
os.rmdir('Test/Folder 2')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 os.rmdir('Test/Folder 2')
#
# OSError: [Errno 66] Directory not empty: 'Test/Folder 2'

# %%
shutil.rmtree('Test/Folder 2')
